# %%
# %run "Preprocessing.ipynb"

# %%
import holoviews as hv
hv.extension('bokeh')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
numRows = 50000
df = pd.read_csv("../../data/train.csv",nrows=numRows)
df, fares = preprocess(df)

# %%
# In HoloViews, use of a single percent sign makes the magic function apply to the entire Jupyter notebook, 
# and use of a double magic sign make the magic function apply only to the code cell in which it resides.
# %opts Scatter [show_grid=True, width=450, height=350] (color='#1f77b4', size=1)
scatter = hv.Scatter(df, 'pickup_longitude','pickup_latitude')

# %%
# scatter

# %%
points = hv.Points(df.iloc[:,0:2])
points.hist(num_bins=100, dimension=['pickup_longitude','pickup_latitude'])
# Out:
# :AdjointLayout
#    :Points   [pickup_longitude,pickup_latitude]
#    :Histogram   [pickup_latitude]   (pickup_latitude_frequency)
#    :Histogram   [pickup_longitude]   (pickup_longitude_frequency)

# %%
taxi_pickups = { x: hv.Scatter(df.loc[np.floor(df['pickup_hour']).isin([x])], 'pickup_longitude','pickup_latitude') for x in range(24)}
taxi_dropoffs = { x: hv.Scatter(df.loc[np.floor(df['pickup_hour']).isin([x])], 'dropoff_longitude','dropoff_latitude') for x in range(24)}

# %%
# %%opts Scatter [show_grid=True, width=450, height=350] (color='red', size=1)
hmap = hv.HoloMap(taxi_pickups, kdims='Hour')
hmap1 = hv.HoloMap(taxi_dropoffs, kdims='Hour')
hmap+hmap1
# Out:
# :Layout
#    .HoloMap.I  :HoloMap   [Hour]
#       :Scatter   [pickup_longitude]   (pickup_latitude)
#    .HoloMap.II :HoloMap   [Hour]
#       :Scatter   [dropoff_longitude]   (dropoff_latitude)
